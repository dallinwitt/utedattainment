# %%
import pandas as pd

# %%
ed_tidy = pd.read_csv('ed_tidy_wnames.csv')
fips = pd.read_csv('utah_fips.csv')

# %%
ed_info = pd.merge(ed_tidy, fips, how = 'left', on = 'county')
ed_info
# Out:
#       sex    age metric    tract            county   value  FIPS
# 0      MF  18-24    POP  1001.00     Beaver County   210.0     1
# 1      MF  18-24    POP  1002.00     Beaver County   284.0     1
# 2      MF  18-24    POP  9601.00  Box Elder County   192.0     3
# 3      MF  18-24    POP  9602.00  Box Elder County   333.0     3
# 4      MF  18-24    POP  9603.00  Box Elder County  1016.0     3
# ...    ..    ...    ...      ...               ...     ...   ...
# 47350   F    65+     B+  2109.00      Weber County    18.5    57
# 47351   F    65+     B+  2110.00      Weber County    12.7    57
# 47352   F    65+     B+  2111.00      Weber County     9.2    57
# 47353   F    65+     B+  2112.01      Weber County    24.4    57
# 47354   F    65+     B+  2112.02      Weber County    18.8    57
#
# [47355 rows x 7 columns]

# %%
ed_info.to_csv('ed_info.csv')
