# %%
import pandas as pd

# %%
ed = pd.read_csv('Utah_Educational_Level_By_Census_Tract_2013.csv')
fips = pd.read_csv('utah_fips.csv')

# %%
ed_merge = pd.merge(ed, fips, how = 'left', on = 'county')
ed_merge
# Out:
#      tract_no            county  Total; Estimate; Population 18 to 24 years  \
# 0     1001.00     Beaver County                                         210
# 1     1002.00     Beaver County                                         284
# 2     9601.00  Box Elder County                                         192
# 3     9602.00  Box Elder County                                         333
# 4     9603.00  Box Elder County                                        1016
# ..        ...               ...                                         ...
# 583   2109.00      Weber County                                         492
# 584   2110.00      Weber County                                         340
# 585   2111.00      Weber County                                         700
# 586   2112.01      Weber County                                         454
# 587   2112.02      Weber County                                         835
#
# ...

# %%
ed_merge.to_csv('ed_untidy.csv')
